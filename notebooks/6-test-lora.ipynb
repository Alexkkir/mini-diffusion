# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/akkirr/Desktop/IT

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from pathlib import Path

import torch
from torch import nan_to_num
from torchvision import transforms
from torch.utils.data import DataLoader

import numpy as np
from PIL import Image
import requests

from datasets import load_dataset
from torchvision.utils import save_image
from torch.optim import Adam

# %%
from mylib import *
from lora import *

# %%
class Attention(nn.Module):
    def __init__(self):
        super().__init__()
        self.QKV = nn.Linear(1, 1)
        self.C = nn.Linear(1, 1)
        self.lrelu = nn.LeakyReLU()

    def forward(self, x):
        return self.C(self.lrelu(self.QKV(x)))


class TimeEmbedding(nn.Module):
    def __init__(self):
        super().__init__()
        self.time_proj = nn.Linear(1, 1)
        self.lrelu = nn.LeakyReLU()

    def forward(self, x):
        return self.lrelu(self.time_proj(x))


class LoraInjected(nn.Module):
    def __init__(self):
        super().__init__()
        self.src_linear = nn.Linear(1, 1)
        self.A = nn.Linear(1, 1)
        self.B = nn.Linear(1, 1)
        self.dropout = nn.Dropout1d()

    def forward(self, x):
        return self.src_linear(x) + self.dropout(self.B(self.A(x)))


class A(nn.Module):
    def __init__(self):
        super().__init__()
        self.just_linear = nn.Linear(1, 1)
        self.attn = Attention()
        self.time_embedder = TimeEmbedding()

    def forward(self, x):
        return self.attn(self.just_linear(x) + self.time_embedder(x))

# %%
from torch.optim import Adam
from copy import deepcopy

a = A()
optim = Adam(a.parameters())

# %%
[x[2] + '.' + x[3] for x in list(find_modules(
        a,
        ["Attention"],
        [nn.Linear],
        [LoraInjected],
    ))]
# Out:
# 				 Attention (<class '__main__.LoraInjected'>,) False
# attn. Attention [<class '__main__.LoraInjected'>] False
# 				 Attention (<class '__main__.LoraInjected'>,) False
# 	 QKV LoraInjectedLinear
# 				 LoraInjectedLinear (<class 'torch.nn.modules.linear.Linear'>,) False
# 	 C LoraInjectedLinear
# 				 LoraInjectedLinear (<class 'torch.nn.modules.linear.Linear'>,) False
# 	 lrelu LeakyReLU
# 				 LeakyReLU (<class 'torch.nn.modules.linear.Linear'>,) False
# 				 LoraInjectedLinear (<class '__main__.LoraInjected'>,) False
# attn.QKV LoraInjectedLinear [<class '__main__.LoraInjected'>] False
# 				 LoraInjectedLinear (<class '__main__.LoraInjected'>,) False
# 	 src_linear Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 lora_down Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 lora_up Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 dropout_layer Dropout1d
# 				 Dropout1d (<class 'torch.nn.modules.linear.Linear'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.QKV.src_linear Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.QKV.lora_down Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.QKV.lora_up Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Dropout1d (<class '__main__.LoraInjected'>,) False
# attn.QKV.dropout_layer Dropout1d [<class '__main__.LoraInjected'>] False
# 				 Dropout1d (<class '__main__.LoraInjected'>,) False
# 				 LoraInjectedLinear (<class '__main__.LoraInjected'>,) False
# attn.C LoraInjectedLinear [<class '__main__.LoraInjected'>] False
# 				 LoraInjectedLinear (<class '__main__.LoraInjected'>,) False
# 	 src_linear Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 lora_down Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 lora_up Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 dropout_layer Dropout1d
# 				 Dropout1d (<class 'torch.nn.modules.linear.Linear'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.C.src_linear Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.C.lora_down Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.C.lora_up Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Dropout1d (<class '__main__.LoraInjected'>,) False
# attn.C.dropout_layer Dropout1d [<class '__main__.LoraInjected'>] False
# 				 Dropout1d (<class '__main__.LoraInjected'>,) False
# 				 LeakyReLU (<class '__main__.LoraInjected'>,) False
# attn.lrelu LeakyReLU [<class '__main__.LoraInjected'>] False
# 				 LeakyReLU (<class '__main__.LoraInjected'>,) False
# ['attn.src_linear',
#  'attn.lora_down',
#  'attn.lora_up',
#  'attn.src_linear',
#  'attn.lora_down',
#  'attn.lora_up']

# %%
inject_lora(
        a,
        2, 0,
        ["Attention"],
        [nn.Linear],
        [LoraInjected],
        verbose=True
    )
# Out:
# 				 Attention (<class '__main__.LoraInjected'>,) False
# attn. Attention [<class '__main__.LoraInjected'>] False
# 				 Attention (<class '__main__.LoraInjected'>,) False
# 	 QKV Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 C Linear
# 				 Linear (<class 'torch.nn.modules.linear.Linear'>,) True
# 		*
# 	 lrelu LeakyReLU
# 				 LeakyReLU (<class 'torch.nn.modules.linear.Linear'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.QKV Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# attn.C Linear [<class '__main__.LoraInjected'>] False
# 				 Linear (<class '__main__.LoraInjected'>,) False
# 				 LeakyReLU (<class '__main__.LoraInjected'>,) False
# attn.lrelu LeakyReLU [<class '__main__.LoraInjected'>] False
# 				 LeakyReLU (<class '__main__.LoraInjected'>,) False
# Injected lora (1x2x1) in attn.QKV
# Injected lora (1x2x1) in attn.C

# %%
import torchvision
model = torchvision.models.resnet18()

inject_lora(
        model,
        2, 0,
        ["BasicBlock"],
        [nn.Conv2d],
        [LoraInjectedConv2d],
        verbose=True
    )
# Out:
# 				 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.0.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer1.1.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 downsample Sequential
# 				 Sequential(
#   (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Sequential(
#   (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.downsample Sequential [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Sequential(
#   (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 0 Conv2d
# 				 Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 1 BatchNorm2d
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.downsample.0 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.0.downsample.1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer2.1.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 downsample Sequential
# 				 Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.downsample Sequential [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 0 Conv2d
# 				 Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 1 BatchNorm2d
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.downsample.0 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.0.downsample.1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer3.1.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 downsample Sequential
# 				 Sequential(
#   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Sequential(
#   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.downsample Sequential [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Sequential(
#   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 0 Conv2d
# 				 Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 1 BatchNorm2d
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.downsample.0 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.0.downsample.1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BasicBlock(
#   (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1. BasicBlock [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BasicBlock(
#   (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 	 conv1 Conv2d
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn1 BatchNorm2d
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 relu ReLU
# 				 ReLU(inplace=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 	 conv2 Conv2d
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'torch.nn.modules.conv.Conv2d'>,) True
# 		*
# 	 bn2 BatchNorm2d
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'torch.nn.modules.conv.Conv2d'>,) False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1.conv1 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1.bn1 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1.relu ReLU [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 ReLU(inplace=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1.conv2 Conv2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# layer4.1.bn2 BatchNorm2d [<class 'lora.lora.LoraInjectedConv2d'>] False
# 				 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) (<class 'lora.lora.LoraInjectedConv2d'>,) False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 import torchvision
#       2 model = torchvision.models.resnet18()
# ----> 4 inject_lora(
#       5         model,
#       6         2, 0,
#       7         ["BasicBlock"],
#       8         [nn.Conv2d],
#       9         [LoraInjectedConv2d],
#      10         verbose=True
#      11     )
#
# File ~/Desktop/IT/annotated-diffusion/lora/lora.py:162, in inject_lora(model, rank, dropout, target_modules, injected_modules, lora_modules, verbose)
#     160 elif isinstance(children, nn.Conv2d):
#     161     lora = LoraInjectedConv2d(children, rank, dropout)
# --> 162     parent[children_name] = lora
#     163     if verbose:
#     164         print(f'Injected lora ({lora.in_channels}x{rank}x{lora.out_channels}) in {parent_name}.{children_name}')
#
# TypeError: 'BasicBlock' object does not support item assignment

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
